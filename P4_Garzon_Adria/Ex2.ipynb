# %%
import logging
import logging.handlers
import sys

# Configuració del logger principal
logger = logging.getLogger('mi_app')
logger.setLevel(logging.DEBUG)  

# Handler per guardar els logs d'informació en un fitxer
info_handler = logging.FileHandler('info.log')
info_handler.setLevel(logging.INFO)

# Handler per guardar els logs d'error en un fitxer
error_handler = logging.FileHandler('error.log')
error_handler.setLevel(logging.ERROR)

# Handler per mostrar els logs a la pantalla
console_handler = logging.StreamHandler(sys.stdout)
console_handler.setLevel(logging.INFO)

# Formatejadors
info_formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
error_formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
console_formatter = logging.Formatter('%(levelname)s - %(message)s')

# Assignem els formatejadors als handlers
info_handler.setFormatter(info_formatter)
error_handler.setFormatter(error_formatter)
console_handler.setFormatter(console_formatter)

# Afegim els handlers al logger principal
logger.addHandler(info_handler)
logger.addHandler(error_handler)
logger.addHandler(console_handler)

# Creació d'un nou logger per generar logs en format CSV
csv_logger = logging.getLogger('csv_logger')
csv_logger.setLevel(logging.INFO)

# Handler per guardar els logs en format CSV
csv_file_handler = logging.FileHandler('csv_log.csv')
csv_file_handler.setLevel(logging.INFO)

# Formatejador per al CSV (format com una línia CSV)
csv_formatter = logging.Formatter('%(asctime)s,%(levelname)s,%(message)s')
csv_file_handler.setFormatter(csv_formatter)

# Afegim el handler CSV al logger CSV
csv_logger.addHandler(csv_file_handler)

# Funció per generar missatges de log
def generar_logs():
    logger.info('Aquest és un missatge de info principal.')
    logger.error('Aquest és un missatge d\'error principal.')

    # Nou logger per logs en format CSV
    csv_logger.info('Aquest és un missatge de info en format CSV.')

# Executar la generació dels logs
generar_logs()
